# %% [markdown]
# # Hello SN1 Students!
#
# Welcome to this example Jupyter Notebook.

# %% [markdown]
# This cell is a markdown cell. This is where we write text for other humans to read. It is called a markdown cell because we can use **markdown syntax** to format the text and spiff it up!
#
# If you are already seeing this block as the formatted output, double click it to see the original markdown, then press the "Run" button in the toolbar above to make it pretty again (it looks like a play symbol)

# %% [markdown]
# Markdown blocks also allow us to display math in LaTeX syntax! We can create an inline equation like $E=mc^2$ or create a block equation:
#
# $$
# x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
# $$

# %%
# This is code cell. In this notebook, the code cells run Python (look at the top right).
# Try running this cell. Notice where the output prints.

print("Hello, SN1")

# %% [markdown]
# When you ran the cell above, did you notice a number appear in the square brackets to the left? This number tells you the order that the code blocks ran in. Try running this next block, and notice the number:

# %%
print("Hello again, SN1")

# %% [markdown]
# Now try running this next block. Notice that there is no print statement in this block, just math:

# %%
x = 5
y = 6
x * y + 100

# %% [markdown]
# The Jupyter notebook assumes that we might want to see the result of our expression (and that we're not just asking Python to do random math for no reason) and so shows it to us anyway.

# %% [markdown]
# Note that the order in which the code blocks run matters. Try running the next two blocks in reverse order:

# %%
my_var = "Good morning!"

# %%
# Try running this block WITHOUT running the above block. Python won't be able to find my_var because it doesn't exist yet!
print(my_var)

# %% [markdown]
# Now try pressing the "Restart kernel and run all cells" button (it looks like a fast forward symbol). Restarting the kernel makes the Python interpreter "forget" what it ran before, giving us a clean slate. Then it will run all the cells again in order from top to bottom.
#
# You may have noticed that the numbers next to the code blocks become asterisks (*) while the code is running. Sometimes it takes Python a moment to get through all the code blocks, especially in a notebook with a lot of them, so the asterisk gives you an indicator of what is happening.
